# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("original DataFrame with Nan\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# original DataFrame with Nan
#          one       two     three
# a -0.367188  0.782140  0.097703
# b       NaN       NaN       NaN
# c  1.070393 -0.621813  0.071244
# d -1.248767  0.099451  1.523081
# e       NaN       NaN       NaN
# f  0.822151  0.169783 -0.253342
#
#
# Dropped DataFrame
#          one       two     three
# a -0.367188  0.782140  0.097703
# c  1.070393 -0.621813  0.071244
# d -1.248767  0.099451  1.523081
# f  0.822151  0.169783 -0.253342

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c'])
print("original DataFrame:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# original DataFrame:
#          one       two     three
# a -1.329614  0.322335  1.873910
# b       NaN       NaN       NaN
# c  0.348550 -1.446789 -0.588917
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -1.329614  0.322335  1.873910
# b  0.000000  0.000000  0.000000
# c  0.348550 -1.446789 -0.588917

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],'two':[60,70,80,0,10]})
print("Original DataFrame:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original DataFrame:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original DataFrame:
#          one       two     three
# a -2.096975  0.552691  0.135471
# b       NaN       NaN       NaN
# c -0.094154  0.043086 -0.692063
# d -0.884584 -0.802915  0.161067
# e       NaN       NaN       NaN
# f  0.061616  0.850796 -0.805110
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNaN-Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original DataFrame:
#          one       two     three
# a -0.541603 -0.696911  0.307401
# b       NaN       NaN       NaN
# c -0.926503  1.248362 -0.967475
# d -0.429545  1.829723 -2.038299
# e       NaN       NaN       NaN
# f -0.102971 -0.097214  0.128737
#
# NaN-Filled with Background values:
#
#         one       two     three
# a -0.541603 -0.696911  0.307401
# b -0.926503  1.248362 -0.967475
# c -0.926503  1.248362 -0.967475
# d -0.429545  1.829723 -2.038299
# e -0.102971 -0.097214  0.128737
# f -0.102971 -0.097214  0.128737
# /tmp/ipython-input-2348680001.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
