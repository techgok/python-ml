# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px

#seaborn package
xpoints=np.array([0,20,120,200])
ypoints=np.array([10,80,100,120,150,180,250])
print(sns.scatterplot(data=ypoints))
print(plt.show())
# Out:
# Axes(0.125,0.11;0.775x0.77)
# None

# %%
print(sns.barplot(data=ypoints))
print(plt.show())
# Out:
# Axes(0.125,0.11;0.775x0.77)
# None

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,6,8,12,14,20])
y = np.array([3,8,1,10,12,16,18])
z = np.array([5,7,9,11,13,15,17])  # added z values

fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')

plt_3d = ax.scatter3D(x, y, z, c=z, cmap='viridis')

plt.colorbar(plt_3d)
plt.show()
